# %%
pip install fuzzywuzzy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fuzzywuzzy in /Users/melodyqian/Library/Python/3.9/lib/python/site-packages (0.18.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from music21 import * 
from music21 import corpus, meter, tempo, expressions
import numpy as np
import pandas as pd
from collections import Counter
import os
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
folder_path = '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/'
paths=[]
filenames=[]
for filename in os.listdir(folder_path):
    if filename.endswith('.mxl'):  # Or the file extension you're working with
        full_path = os.path.join(folder_path, filename)
        paths.append(full_path)
        filenames.append(filename)

for i in range(len(filenames)):
    filenames[i] = filenames[i].replace('_', ' ')  
    filenames[i] = filenames[i].replace('.mxl', '')

pathsdict=dict(zip(filenames, paths))
# Out:
# {'Haydn Piano Sonata in F Major HobXVI 23 (1)': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Haydn_Piano_Sonata_in_F_Major_HobXVI_23 (1).mxl', 'Fugue No. 16 BWV 885 in G Minor': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Fugue_No._16_BWV_885_in_G_Minor.mxl', 'Piano Sonata Sz.80  Bla Bartk 2. Sostenuto e pesante': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Piano_Sonata_Sz.80__Bla_Bartk_2._Sostenuto_e_pesante.mxl', 'Prelude No. 22 BWV 867 in B Minor': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Prelude_No._22_BWV_867_in_B_Minor.mxl', 'Sonata No. 84 In D major - Padre Antonio Soler': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Sonata_No._84_In_D_major_-_Padre_Antonio_Soler.mxl', 'Fugue in E Minor BWV 914 By Johann Sebastian Bach': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Fugue_in_E_Minor_BWV_914_By_Johann_Sebastian_Bach.mxl', 'Phrygian Gates China Gates  John Adams': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Phrygian_Gates_China_Gates__John_Adams.mxl', 'Siciliano - Flute Sonata in E-flat major BWV 1031 - Johann Sebastian Bach': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Siciliano_-_Flute_Sonata_in_E-flat_major_BWV_1031_-_Johann_Sebastian_Bach.mxl', 'Eight Improvisations on Hungarian Peasant Songs': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Eight_Improvisations_on_Hungarian_Peasant_Songs.mxl', 'Piano Sonata Sz.80  Bla Bartk 2. Sostenuto e pesante (1)': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Piano_Sonata_Sz.80__Bla_Bartk_2._Sostenuto_e_pesante (1).mxl', 'Beethoven Piano Sonata in A-flat major op. 110 iii (2)': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Beethoven_Piano_Sonata_in_A-flat_major_op._110_iii (2).mxl', 'Beethoven - Piano Sonata No. 28 in A Major Op. 101 1st Movement': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Beethoven_-_Piano_Sonata_No._28_in_A_Major_Op._101_1st_Movement.mxl', 'Prelude No. 24 BWV 893 in B Minor': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Prelude_No._24_BWV_893_in_B_Minor.mxl', 'Intermezzo Op. 118 No. 2 A Major unedited - Johannes Brahms': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Intermezzo_Op._118_No._2_A_Major_unedited_-_Johannes_Brahms.mxl', 'Prelude No. 23 BWV 892 in B Major': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Prelude_No._23_BWV_892_in_B_Major.mxl', 'Fugue No. 17 BWV 886 in A Major': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Fugue_No._17_BWV_886_in_A_Major.mxl', 'Piano Sonata No. 9 in E Major Op.14 No.1 2nd Movement Allegretto - Ludwig van Beethoven': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Piano_Sonata_No._9_in_E_Major_Op.14_No.1_2nd_Movement_Allegretto_-_Ludwig_van_Beethoven.mxl', 'J.S. Bach - English Suite no.3 - Allemande BWV 808': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/J.S._Bach_-_English_Suite_no.3_-_Allemande_BWV_808.mxl', 'Feux Follets - Piano Tiles 2': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Feux_Follets_-_Piano_Tiles_2.mxl', 'Piano Sonata No. 13 in E-Flat Major Op.27 No.1 2nd Movement - Ludwig van Beethoven': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Piano_Sonata_No._13_in_E-Flat_Major_Op.27_No.1_2nd_Movement_-_Ludwig_van_Beethoven.mxl', 'Fugue No. 17 BWV 862 in A Major': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Fugue_No._17_BWV_862_in_A_Major.mxl', 'Transcendental Etude S.139 No.5 Feux follets  Liszt': '/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/total57/Transcendental_Etude_S.139_No.5_Feux_follets__Liszt.mxl', '7 Fantasy for Piano Op.116 No.1  ...

# %%
json=pd.read_json("/Users/melodyqian/Documents/GitHub/pianocompetitionpredictions/scrape-musescore-2/sheet_music_results.json")
difficultymetric=json.dropna(subset=['title'])

# %%
def match_titles_to_files(df, filenames, dict, threshold=70):
    matched_files = []
    for title in df['title']:
        match = process.extractOne(title, filenames, scorer=fuzz.token_sort_ratio)
        if match and match[1] >= threshold: 
           matched_files.append(dict.get(match[0], np.nan))  
        else:
            matched_files.append(np.nan)  
    return matched_files

# %%
filekeys = list(pathsdict.keys())
difficultymetric['matched_file'] = match_titles_to_files(difficultymetric, filekeys, pathsdict)
# Out:
# /var/folders/bf/j0nvm48j18b4mlfybgxf_1fm0000gn/T/ipykernel_7379/3898033698.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   difficultymetric['matched_file'] = match_titles_to_files(difficultymetric, filekeys, pathsdict)

# %%
difficultymetric[['title', 'matched_file']]
difficultymetric=difficultymetric.dropna(subset=['matched_file'])
difficultymetric
# Out:
#                                                  query  \
# 22          Bach English Suite No.2 in A minor BWV 807
# 23          Bach English Suite No.3 in G minor BWV 808
# 29           Bach French Suite No.5 in G Major BWV 816
# 30                    Bach Goldberg Variations BWV 988
# 35                Bach Partita No.2 in C Minor BWV 826
# 40              Bach Prelude and Fugue G minor BWV 885
# 41           Bach Prelude and Fugue in A minor BWV 865
# 42           Bach Prelude and Fugue in A minor BWV 889
# 43      Bach Prelude and Fugue in A-flat major BWV 862
# 44      Bach Prelude and Fugue in A-flat major BWV 886
# 46           Bach Prelude and Fugue in B major BWV 868
# 47           Bach Prelude and Fugue in B major BWV 892
# 48           Bach Prelude and Fugue in B minor BWV 869
# 49           Bach Prelude and Fugue in B minor BWV 893
# 50      Bach Prelude and Fugue in B-flat major BWV 866
# 52      Bach Prelude and Fugue in B-flat Minor BWV 867
# 53      Bach Prelude and Fugue in B-flat minor BWV 891
# 56           Bach Prelude and Fugue in C major BWV 870
# 58           Bach Prelude and Fugue in C minor BWV 847
# 59           Bach Prelude and Fugue in C minor BWV 871
# 61     Bach Prelude and Fugue in C-sharp major BWV 872
# 62     Bach Prelude and Fugue in C-sharp minor BWV 849
# 66           Bach Prelude and Fugue in D major BWV 874
# 67           Bach Prelude and Fugue in D minor BWV 875
# 68     Bach Prelude and Fugue in D-sharp minor BWV 877
# 69           Bach Prelude and Fugue in E major BWV 878
# 71           Bach Prelude and Fugue in E minor BWV 879
# 73      Bach Prelude and Fugue in E-flat Major BWV 852
# 74      Bach Prelude and Fugue in E-flat Minor BWV 853
# 76           Bach Prelude and Fugue in F major BWV 880
# 77           Bach Prelude and Fugue in F minor BWV 881
# 78     Bach Prelude and Fugue in F-sharp major BWV 882
# 79           Bach Prelude and Fugue in G major BWV 860
# 80           Bach Prelude and Fugue in G minor BWV 861
# 81           Bach Prelude and Fugue in G minor BWV 885
# 83     Bach Prelude and Fugue in G-sharp minor BWV 863
# 148              Beethoven Sonata in A major Op.2 No.2
# 153              Beethoven Sonata in C Major Op.2 No.3
# 159       Beethoven Sonata in C-sharp minor Op.27 No.2
# 160             Beethoven Sonata in D Major Op.10 No.3
# 161                  Beethoven Sonata in D major Op.28
# 169              Beethoven Sonata in E-flat Major Op.7
# 171             Beethoven Sonata in F major Op.10 No.2
# 174              Beethoven Sonata in F minor op.2 no.1
# 179         Beethoven Sonata No.3 in C Major Op.2 No.3
# 192                      Bortkiewicz 10 Preludes Op.33
# 202           Brahms Intermezzo in A Major Op.118 No.2
# 206           Brahms Intermezzo in F minor Op.118 No.4
# 208                        Brahms Klavierstucke Op.118
# 261                 Chopin Etude in A Minor Op.10 No.2
# 326                Chopin Sonata in B-flat minor Op.35
# 328           Chopin Sonata No.2 in B-flat minor Op.35
# 71   /Users/melodyqian/Documents/GitHub/pianocompet...
# 73   /Users/melodyqian/Documents/GitHub/pianocompet...
# 74   /Users/melodyqian/Documents/GitHub/pianocompet...
# 76   /Users/melodyqian/Documents/GitHub/pianocompet...
# 77   /Users/melodyqian/Documents/GitHub/pianocompet...
# 78   /Users/melodyqian/Documents/GitHub/pianocompet...
# 79   /Users/melodyqian/Documents/GitHub/pianocompet...
# 80   /Users/melodyqian/Documents/GitHub/pianocompet...
# 81   /Users/melodyqian/Documents/GitHub/pianocompet...
# 83   /Users/melodyqian/Documents/GitHub/pianocompet...
# 148  /Users/melodyqian/Documents/GitHub/pianocompet...
# 153  /Users/melodyqian/Documents/GitHub/pianocompet...
# 159  /Users/melodyqian/Documents/GitHub/pianocompet...
# 160  /Users/melodyqian/Documents/GitHub/pianocompet...
# 161  /Users/melodyqian/Documents/GitHub/pianocompet...
# 169  /Users/melodyqian/Documents/GitHub/pianocompet...
# 171  /Users/melodyqian/Documents/GitHub/pianocompet...
# 174  /Users/melodyqian/Documents/GitHub/pianocompet...
# 179  /Users/melodyqian/Documents/GitHub/pianocompet...
# 192  /Users/melodyqian/Documents/GitHub/pianocompet...
# 202  /Users/melodyqian/Documents/GitHub/pianocompet...
# 206  /Users/melodyqian/Documents/GitHub/pianocompet...
# 208  /Users/melodyqian/Documents/GitHub/pianocompet...
# 261  /Users/melodyqian/Documents/GitHub/pianocompet...
# 326  /Users/melodyqian/Documents/GitHub/pianocompet...
# 328  /Users/melodyqian/Documents/GitHub/pianocompet...
# 621  /Users/melodyqian/Documents/GitHub/pianocompet...
# 623  /Users/melodyqian/Documents/GitHub/pianocompet...
# 628  /Users/melodyqian/Documents/GitHub/pianocompet...
# 689  /Users/melodyqian/Documents/GitHub/pianocompet...
# 741  /Users/melodyqian/Documents/GitHub/pianocompet...
# 742  /Users/melodyqian/Documents/GitHub/pianocompet...
# 887  /Users/melodyqian/Documents/GitHub/pianocompet...

# %%
note_durations = {
    '32nd_and_shorter': 0.125,
    '16th': 0.25,
    'eighth': 0.5,
    'quarter': 1,
    'dotted quarter': 1.5,
    'half': 2,
    'dotted half': 3,
    'whole': 4
}

# %%
def analyze(filepath):
    filepath=str(filepath)
    score=converter.parse(filepath)
    flatscore=score.flatten()
    def notecount(flatscore):
       num_notes=0
       for elem in flatscore:
           if isinstance(elem, note.Note):
              num_notes += 1
           elif isinstance(elem, chord.Chord):
              num_notes += len(elem.pitches)
       return(num_notes)
    notecounts=notecount(flatscore)
    chords= [element for element in flatscore if isinstance(element, chord.Chord)]
    numberchords= len(chords)   
    def chordpitchdistances(chords):
        pitchdistances= []
        for i in range(len(chords)-1):
            firstchord= chords[i]
            secondchord= chords[i+1]
            rootInterval=interval.Interval(firstchord.root(),secondchord.root())
            pitchdistances.append(rootInterval.semitones)
        return(pitchdistances)
    pitchdistances=chordpitchdistances(chords)
    chord_abs_dis= [abs(dis) for dis in pitchdistances]
    meanchorddis= np.mean(chord_abs_dis)
    def chordtimedistances(chords):
        timedistances=[]
        for i in range(len(chords)-1):
            firstchord= chords[i]
            secondchord= chords[i+1]
            time_difference = secondchord.offset - firstchord.offset
            timedistances.append(time_difference) 
        return timedistances
    chordtimedistance=chordtimedistances(chords)
    meantimedistance=np.mean(chordtimedistance)
    key=flatscore.analyze('key')
    timesignature=flatscore.getElementsByClass(meter.TimeSignature)
    timesignaturechanges=len(timesignature)
    def findtrills(score):
        trills=0
        totalbeats=0
        for element in score.notesAndRests:
            if element.expressions:  # Check if the note has expressions
                for expr in element.expressions:
                    if isinstance(expr, expressions.Trill):  # Check if it's a trill
                        trills+= 1 
                        totalbeats+=element.quarterLength
        return [trills, totalbeats]
    trill_length=findtrills(flatscore)
    tempos= flatscore.getElementsByClass(tempo.MetronomeMark)
    sorted_tempos = sorted(tempos, key=lambda tm: tm.measureNumber)
    weighted_tempo=[]
    for i in range(len(sorted_tempos)):
        current_bpm = sorted_tempos[i].getQuarterBPM()
        current_measure = sorted_tempos[i].measureNumber
        if i < len(sorted_tempos) - 1:
            next_measure = sorted_tempos[i + 1].measureNumber
            duration = next_measure - current_measure
        else:
            # If this is the last tempo, assume it lasts to the end of the piece
            duration = score.highestTime
        weighted_tempo.append((current_bpm, duration))
    total_weight = sum(duration for _, duration in weighted_tempo)
    weighted_mean = (
    sum(bpm * duration for bpm, duration in weighted_tempo) / total_weight
    if total_weight != 0 else 0
    )
    num_measures = len(score.recurse().getElementsByClass('Measure'))
    duration_counter = Counter(note.duration.quarterLength for note in score.recurse().notes)
    def count_notes(score, duration_counter):
        note_counts= {}
        for name, duration in note_durations.items():
            if name=='32nd_and_shorter':
                note_counts[name]= sum(count for d, count in duration_counter.items() if d<=duration)
            else:
                note_counts[name]=duration_counter[duration]
        return note_counts
    notedict= count_notes(score,duration_counter)
    return{
        "numberofnotes": notecounts,
        "numberofchords": numberchords,
        "numberofmeasures": num_measures,
        "meandistancebetweenchords": meanchorddis,
        "meantimebetweenchords": meantimedistance,
        "key": key,
        "timechanges": timesignaturechanges,
        "trillslength": trill_length,
        "avgtempo" : weighted_mean,
        **notedict
    }

# %%
results_df = difficultymetric['matched_file'].apply(analyze).apply(pd.Series)
# Out:
# /Users/melodyqian/Library/Python/3.9/lib/python/site-packages/numpy/_core/fromnumeric.py:3596: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/melodyqian/Library/Python/3.9/lib/python/site-packages/numpy/_core/_methods.py:138: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
results_df['Title'] = difficultymetric['title'].values
# Out:
# 22                  Bach BWV 807 Allemande English Suite
# 23     J.S. Bach - English Suite no.3 - Allemande, BW...
# 29     J.S. Bach - French Suite No. 5 Gavotte in G Ma...
# 30              Goldberg Variations BWV 988, Variation 1
# 35     Bach JS - Partita No 2 in C minor BMV 826 Move...
# 40                       Fugue No. 16 BWV 885 in G Minor
# 41                     Prélude No. 20 BWV 865 in A Minor
# 42                     Prélude No. 20 BWV 889 in A Minor
# 43                      Fugue No. 17 BWV 862 in A♭ Major
# 44                      Fugue No. 17 BWV 886 in A♭ Major
# 46                       Fugue No. 23 BWV 868 in B Major
# 47                     Prélude No. 23 BWV 892 in B Major
# 48                       Fugue No. 24 BWV 869 in B Minor
# 49                     Prélude No. 24 BWV 893 in B Minor
# 50                       BWV 866 - Fugue in B flat Major
# 52                    Prélude No. 22 BWV 867 in B♭ Minor
# 53                      Fugue No. 22 BWV 891 in B♭ Minor
# 56                        Fugue No. 1 BWV 870 in C Major
# 58                        Fugue No. 2 BWV 847 in C Minor
# 59                        Fugue No. 2 BWV 871 in C Minor
# 61              ONLINE_Prélude No. 3 BWV 872 in C♯ Major
# 62                     Prélude No. 4 BWV 849 in C♯ Minor
# 66                        Fugue No. 5 BWV 874 in D Major
# 67                      Prélude No. 6 BWV 875 in D Minor
# 68                     Prélude No. 8 BWV 877 in D♯ Minor
# 69                        Fugue No. 9 BWV 878 in E Major
# 71                       Fugue No. 10 BWV 879 in E Minor
# 73                     Prélude No. 7 BWV 852 in E♭ Major
# 74                       Fugue No. 8 BWV 853 in D♯ Minor
# 76                     Prélude No. 11 BWV 880 in F Major
# 77                     Prélude No. 12 BWV 881 in F Minor
# 78                    Prélude No. 13 BWV 882 in F♯ Major
# 79                     Prélude No. 15 BWV 860 in G Major
# 80                       Fugue No. 16 BWV 861 in G Minor
# 81                       Fugue No. 16 BWV 885 in G Minor
# 83                      Fugue No. 18 BWV 863 in G♯ Minor
# 148    Piano Sonata No. 2 in A Major, Op. 2 No. 2 – L...
# 153    Piano Sonata No.3 mv.3 in C Major - L. v. Beet...
# 159    Beethoven - Piano Sonata No. 14 in C Sharp Min...
# 160    Piano Sonata No. 7 in D Major, Op.10 No.3, 1st...
# 161    Piano Sonata No. 15 in D Major, Op.28 "Pastora...
# 169    Piano Sonata No. 4 in E-flat Major, Op.7 "Gran...
# 171    Piano Sonata No. 6 in F Major, Op.10 No.2, 3rd...
# 174    Beethoven - Sonata in F minor Op.2 No.1 Moveme...
# 179    Piano Sonata No.3 mv.3 in C Major - L. v. Beet...
# 192      10 Preludes, op. 33, No. 2 – Sergei Bortkiewicz
# 202    Intermezzo in A Major, Op 118, No. 2 – Johanne...
# 206                      Intermezzo op. 118 nº. 4 Brahms
# 208                     Brahms- Intermezzo Op. 118 No. 2
# 261                       Étude Opus 10 No. 2 in A Minor
# 326    Chopin - Piano Sonata No. 2 in B Flat Minor, O...
# 328    Chopin - Piano Sonata No. 2 in B Flat Minor, O...
# 621    Transcendental Etude No. 3: Paysage – Franz Liszt
# 623                         Feux Follets - Piano Tiles 2
# 628         Liszt - Transcendental Etude No. 4 (Mazeppa)
# 689                           Eine Kleine Gigue - Mozart
# 741    Mozart - Piano Sonata in C minor K 457 No. 14 ...
# 742    Mozart - Piano Sonata in C minor K 457 No. 14 ...
# 887    Variations On A Theme Of Corelli, Op.42, Var. ...
# Name: Title, dtype: object

# %%
results_df.to_csv("Difficulty_Metric_Sample.csv", index=False)
